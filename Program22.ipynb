# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_eligible(age):
    return age >= 18

# Input
age = int(input("Enter age: "))

# Output
if is_eligible(age):
    print("Eligible")
else:
    print("Not Eligible")
