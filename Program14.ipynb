# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def even(a):
    if a % 2 == 0:
        print(a)

# Input
n = int(input("Enter N: "))

# Output
print("Even numbers from 1 to", n, "are:")

for i in range(1, n + 1):
    even(i)
# Out:
# Enter N: 3
# Even numbers from 1 to 3 are:
# 2
