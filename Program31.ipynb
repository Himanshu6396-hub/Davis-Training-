# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input("Enter price: "))
discount = float(input("Enter discount %: "))

discount_amount = (discount / 100) * price
final = price - discount_amount

print("Final price after discount:", final)
