# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter N: "))

print("Even numbers list:")

i = 2
while i <= n:
    print(i, end=" ")
    i += 2
