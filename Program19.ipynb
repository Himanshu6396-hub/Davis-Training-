# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def even(a):
    for i in range(1, n + 1):
      if i% 2 == 0:
        print(i)

# Input
n = int(input("Enter N: "))

# Output
print("Even numbers from 1 to", n, "are:")


even(n)
