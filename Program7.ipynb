# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_vote(age):
    if age >= 18:
        return "Eligible"
    else:
        return "Not Eligible"

# Input
age = int(input("Enter age: "))

# Function call
result = check_vote(age)

# Output
print("You are", result, "to vote")
