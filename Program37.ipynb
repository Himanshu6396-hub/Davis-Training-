# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = float(input("Enter price: "))
d = float(input("Enter discount %: "))

# Using direct formula
final = p * (100 - d) / 100

print("Final price after discount:", final)
