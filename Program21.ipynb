# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def discount_bill():
    price = float(input("Enter price: "))
    discount = float(input("Enter discount %: "))

    final_price = price - (price * discount / 100)
    return final_price

# Function call
print("Final price after discount:", discount_bill())
