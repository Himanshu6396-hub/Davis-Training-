# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu6396-hub/Davis-Training-/blob/main/Program17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_vote():
    age = int(input("Enter age: "))

    if age >= 18:
        print("Eligible")
    else:
        print("Not Eligible")

# Function call
check_vote()
